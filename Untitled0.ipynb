# %% [markdown]
# <a href="https://colab.research.google.com/github/palombarini1207/auladeP.A/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 5
b = 6
t= a+b

# %% [markdown]
# aula de programação
#  . intrudução a programação

# %%
print (t)
# Out:
# 11

# %%
# tipos núméricos
Idade= 15 #int
altura= 1.89 #float
numero_complexo= 2 + 3j #complex

#tipo de texto
nome= "Daniel"  #str

#tipo booleano
esta_chovendo = False #bool

#tipo lista  (mutável)
numeros = {1,2,3,4,5}  #list

#tipo tupla (imutável)
coordenadas= (10,20) #tuple

#tipo conjunto (valores unicos)
vogais = {'a','e','i','o','u'} #set

#tipo dicionário  (valores únicos)
pessoa= {"nome":"Daniel", "Daniel": 15} #dict

# %%
print ("Nome: {nome}, Idade: {idade}, Altura {altura}")
# Out:
# Nome: {nome}, Idade: {idade}, Altura {altura}
