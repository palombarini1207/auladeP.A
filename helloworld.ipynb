# %% [markdown]
# <a href="https://colab.research.google.com/github/palombarini1207/auladeP.A/blob/main/helloworld.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("hello world!")
# Out:
# hello world!
