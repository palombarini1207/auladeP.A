# %% [markdown]
# <a href="https://colab.research.google.com/github/palombarini1207/auladeP.A/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aula de programação e algoritmo
#
# * calcular uma área
#
# #entrada de dados
#
# ler lado1
# ler lado2
#
# #processamento
#
# área = lado1 * lado2
#
# #saída
#
# escrever total da área

# %%
# Variável que recebe o valor dos lados

# Entrada
lado_1 = 7
lado_2 = 3

# %%
# Processamento
area = lado_1 * lado_2

# %%
# Saída
print (f" O total da area calculada: {area} metros quadrados")
# Out:
#  O total da area calculada: 21 metros quadrados

# %% [markdown]
# Operadores aritiméticos
#
#
# 1. soma = +
# 2. subtração= -
# 3. multiplicação = *
# 4. divisão = /

# %% [markdown]
# atividade
#
# fazer um algoritmo e depois o programa que recebe 4 notas do aluno e calcula a média aritmética e imprimi a média

# %% [markdown]
# # Entrada
# variavel das notas dos alunos e colocar a nota dos alunos
#
# # processamento
# média dos alunos, media = (aluno_1 + aluno_2 = aluno_3 + aluno_4) / 4
#
# # saída
# mostrar o resultado da media
# print (f" A media do aluno é: {media}")

# %%
# processamento
media = (aluno_1 + aluno_2 + aluno_3 + aluno_4) / 4

# %%
# variaveis das notas dos alunos

# Entrada
aluno_1= 5
aluno_2= 8
aluno_3= 9
aluno_4= 3

# %%
# saída
media = (aluno_1 + aluno_2 + aluno_3 + aluno_4) / 4

# %%
print (f" A média do aluno é: {media}")
# Out:
#  A média do aluno é: 6.25

# %% [markdown]
# faça um algoritmo que receba um numero e calcule o dobro desse numero

# %%
#entrada
numero_1 = 5

# %%
# processamento
# variaveis
media = (numero_1) * 2

# %%
# saída
print (f" O dobro do numero é: {media}")
# Out:
#  O dobro do numero é: 10
